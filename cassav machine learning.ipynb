# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pd.read_csv("Female_Mps.csv")
fem=pd.read_csv("Female_Mps.csv")
fem
# Out:
#                             country  1945  1946  1947   1948   1949   1950  \
# 0                       Afghanistan   NaN   NaN   NaN    NaN    NaN    NaN
# 1                            Angola   NaN   NaN   NaN    NaN    NaN    NaN
# 2                           Albania  3.66  6.46  8.81  10.80  12.50  14.10
# 3                           Andorra   NaN   NaN   NaN    NaN    NaN    NaN
# 4              United Arab Emirates   NaN   NaN   NaN    NaN    NaN    NaN
# ..                              ...   ...   ...   ...    ...    ...    ...
# 179                          Uganda   NaN   NaN   NaN    NaN    NaN    NaN
# 180                         Ukraine   NaN   NaN   NaN    NaN    NaN    NaN
# 181  St. Vincent and the Grenadines   NaN   NaN   NaN    NaN    NaN    NaN
# 182                           Samoa   NaN   NaN   NaN    NaN    NaN    NaN
# 183                    South Africa   NaN   NaN   NaN   1.31   1.43   1.54
#
# ...

# %%
fem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 78 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  184 non-null    object
#  1   1945     17 non-null     float64
#  2   1946     34 non-null     float64
#  3   1947     40 non-null     float64
#  4   1948     48 non-null     float64
#  5   1949     51 non-null     float64
#  6   1950     53 non-null     float64
#  7   1951     56 non-null     float64
#  8   1952     59 non-null     float64
#  9   1953     60 non-null     float64
#  10  1954     62 non-null     float64
#  11  1955     64 non-null     float64
#  12  1956     64 non-null     float64
#  13  1957     66 non-null     float64
#  14  1958     67 non-null     float64
#  15  1959     70 non-null     float64
#  16  1960     78 non-null     float64
#  17  1961     82 non-null     float64
#  18  1962     85 non-null     float64
#  19  1963     90 non-null     float64
# ...

# %%
fem.isnull().sum()
# Out:
# country      0
# 1945       167
# 1946       150
# 1947       144
# 1948       136
#           ...
# 2017         9
# 2018         9
# 2019         1
# 2020         2
# 2021         2
# Length: 78, dtype: int64

# %%
fem.describe()
# Out:
#             1945       1946       1947       1948       1949       1950  \
# count  17.000000  34.000000  40.000000  48.000000  51.000000  53.000000
# mean    2.874118   2.946471   3.166000   2.847500   3.242745   3.573585
# std     2.684006   2.942937   3.444616   3.483672   4.209952   4.567136
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     2.850000   2.140000   2.410000   1.885000   1.670000   2.080000
# 75%     4.670000   4.525000   4.675000   3.755000   3.930000   4.670000
# max     9.000000   9.670000  12.500000  11.700000  17.700000  17.600000
#
#             1951       1952       1953       1954  ...        2012  \
# count  56.000000  59.000000  60.000000  62.000000  ...  174.000000
# mean    4.096786   4.384915   4.381833   4.379839  ...   20.136609
# std     5.485465   5.571737   5.467268   5.576838  ...   11.656767
# ...

# %%
fem.bfill()
# Out:
#                             country  1945  1946  1947   1948   1949   1950  \
# 0                       Afghanistan  3.66  6.46  8.81  10.80  12.50  14.10
# 1                            Angola  3.66  6.46  8.81  10.80  12.50  14.10
# 2                           Albania  3.66  6.46  8.81  10.80  12.50  14.10
# 3                           Andorra  4.21  0.00  0.00   0.00   5.99  11.40
# 4              United Arab Emirates  4.21  0.00  0.00   0.00   5.99  11.40
# ..                              ...   ...   ...   ...    ...    ...    ...
# 179                          Uganda   NaN   NaN   NaN   1.31   1.43   1.54
# 180                         Ukraine   NaN   NaN   NaN   1.31   1.43   1.54
# 181  St. Vincent and the Grenadines   NaN   NaN   NaN   1.31   1.43   1.54
# 182                           Samoa   NaN   NaN   NaN   1.31   1.43   1.54
# 183                    South Africa   NaN   NaN   NaN   1.31   1.43   1.54
#
# ...

# %%
fem.ffill()
# Out:
#                             country  1945  1946  1947   1948   1949   1950  \
# 0                       Afghanistan   NaN   NaN   NaN    NaN    NaN    NaN
# 1                            Angola   NaN   NaN   NaN    NaN    NaN    NaN
# 2                           Albania  3.66  6.46  8.81  10.80  12.50  14.10
# 3                           Andorra  3.66  6.46  8.81  10.80  12.50  14.10
# 4              United Arab Emirates  3.66  6.46  8.81  10.80  12.50  14.10
# ..                              ...   ...   ...   ...    ...    ...    ...
# 179                          Uganda  0.00  1.81  1.51   1.21   0.91   0.61
# 180                         Ukraine  0.00  1.81  1.51   1.21   0.91   0.61
# 181  St. Vincent and the Grenadines  0.00  1.81  1.51   1.21   0.91   0.61
# 182                           Samoa  0.00  1.81  1.51   1.21   0.91   0.61
# 183                    South Africa  0.00  1.81  1.51   1.31   1.43   1.54
#
# ...

# %%
fem.isnull().sum()
# Out:
# country      0
# 1945       167
# 1946       150
# 1947       144
# 1948       136
#           ...
# 2017         9
# 2018         9
# 2019         1
# 2020         2
# 2021         2
# Length: 78, dtype: int64

# %%
fem.drop_duplicates()
# Out:
#                             country  1945  1946  1947   1948   1949   1950  \
# 0                       Afghanistan   NaN   NaN   NaN    NaN    NaN    NaN
# 1                            Angola   NaN   NaN   NaN    NaN    NaN    NaN
# 2                           Albania  3.66  6.46  8.81  10.80  12.50  14.10
# 3                           Andorra   NaN   NaN   NaN    NaN    NaN    NaN
# 4              United Arab Emirates   NaN   NaN   NaN    NaN    NaN    NaN
# ..                              ...   ...   ...   ...    ...    ...    ...
# 179                          Uganda   NaN   NaN   NaN    NaN    NaN    NaN
# 180                         Ukraine   NaN   NaN   NaN    NaN    NaN    NaN
# 181  St. Vincent and the Grenadines   NaN   NaN   NaN    NaN    NaN    NaN
# 182                           Samoa   NaN   NaN   NaN    NaN    NaN    NaN
# 183                    South Africa   NaN   NaN   NaN   1.31   1.43   1.54
#
# ...

# %%
fem=fem.drop_duplicates()

# %%
cont_data=fem.select_dtypes(exclude=("object"))
cat_data=fem.select_dtypes(include=("object"))

# %%
cont_data
# Out:
#      1945  1946  1947   1948   1949   1950   1951   1952   1953   1954  ...  \
# 0     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 1     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 2    3.66  6.46  8.81  10.80  12.50  14.10  13.50  12.90  12.40  11.90  ...
# 3     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 4     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# ..    ...   ...   ...    ...    ...    ...    ...    ...    ...    ...  ...
# 179   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 180   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 181   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 182   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 183   NaN   NaN   NaN   1.31   1.43   1.54   1.66   1.77   1.89   1.61  ...
#
# ...

# %%
cat_data
# Out:
#                             country
# 0                       Afghanistan
# 1                            Angola
# 2                           Albania
# 3                           Andorra
# 4              United Arab Emirates
# ..                              ...
# 179                          Uganda
# 180                         Ukraine
# 181  St. Vincent and the Grenadines
# 182                           Samoa
# 183                    South Africa
#
# [184 rows x 1 columns]

# %%
plt.figure(figsize=(10,10))
for i,col in enumerate(cont_data):
    plt.subplot(10,10,i+1)
    plt.boxplot(fem[col])
    plt.title(col)
    plt.ylabel(f"frequency")
plt.tight_layout()
plt.show()

# %%
def remove_outliers(columns):
    for column in columns:
        q1=fem[column].quantile(.25)
        q3=fem[column].quantile(.75)
        IQR=q3-q1
        upper_bound=q3+IQR*1.5
        lower_bound=q1-IQR*1.5
        fem[column]=np.where(fem[column]>upper_bound,upper_bound,fem[column])
        fem[column]=np.where(fem[column]<lower_bound,lower_bound,fem[column])

# %%
cont_data
# Out:
#      1945  1946  1947   1948   1949   1950   1951   1952   1953   1954  ...  \
# 0     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 1     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 2    3.66  6.46  8.81  10.80  12.50  14.10  13.50  12.90  12.40  11.90  ...
# 3     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 4     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# ..    ...   ...   ...    ...    ...    ...    ...    ...    ...    ...  ...
# 179   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 180   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 181   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 182   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 183   NaN   NaN   NaN   1.31   1.43   1.54   1.66   1.77   1.89   1.61  ...
#
# ...

# %%
remove_outliers([''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Muhamad\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 remove_outliers([''])
#
# ...
